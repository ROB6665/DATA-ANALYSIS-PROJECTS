# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df=pd.read_csv("pokemon.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      359 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.describe(include="object")
# Out:
#            Name Type 1  Type 2
# count       800    800     359
# unique      800     18      18
# top     Moltres  Water  Flying
# freq          1    112      81

# %%
df.shape
# Out:
# (800, 12)

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        441
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# #              0.000
# Name           0.000
# Type 1         0.000
# Type 2        55.125
# HP             0.000
# Attack         0.000
# Defense        0.000
# Sp. Atk        0.000
# Sp. Def        0.000
# Speed          0.000
# Generation     0.000
# Legendary      0.000
# dtype: float64

# %%
# df.drop(columns=["Type 2","#"],inplace=True)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.shape
# Out:
# (800, 12)

# %%
len(df["Type 1"].unique())
# Out:
# 18

# %%
for i in df["Name"]:
    print(i)
# Out:
# Bulbasaur
# Ivysaur
# Venusaur
# VenusaurMega Venusaur
# Charmander
# Charmeleon
# Charizard
# CharizardMega Charizard X
# CharizardMega Charizard Y
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree
# Weedle
# Kakuna
# Beedrill
# BeedrillMega Beedrill
# Pidgey
# Pidgeotto
# Pidgeot
# PidgeotMega Pidgeot
# Rattata
# Raticate
# Spearow
# Fearow
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran (Female)
# Nidorina
# Nidoqueen
# Nidoran (Male)
# Nidorino
# Nidoking
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff
# Wigglytuff
# Zubat
# Golbat
# Oddish
# Gloom
# Vileplume
# Paras
# Parasect
# Venonat
# Venomoth
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# Arcanine
# Poliwag
# Poliwhirl
# Poliwrath
# Abra
# Kadabra
# Alakazam
# AlakazamMega Alakazam
# Machop
# Machoke
# Machamp
# Bellsprout
# Weepinbell
# Victreebel
# Tentacool
# Tentacruel
# Geodude
# Graveler
# Golem
# ...

# %%
df[["Name","HP","Attack"]][400:411]
# Out:
#                         Name   HP  Attack
# 400                  Walrein  110      80
# 401                 Clamperl   35      64
# 402                  Huntail   55     104
# 403                 Gorebyss   55      84
# 404                Relicanth  100      90
# 405                  Luvdisc   43      30
# 406                    Bagon   45      75
# 407                  Shelgon   65      95
# 408                Salamence   95     135
# 409  SalamenceMega Salamence   95     145
# 410                   Beldum   40      55

# %%
df.iloc[9]
# Out:
# #                    7
# Name          Squirtle
# Type 1           Water
# Type 2             NaN
# HP                  44
# Attack              48
# Defense             65
# Sp. Atk             50
# Sp. Def             64
# Speed               43
# Generation           1
# Legendary        False
# Name: 9, dtype: object

# %%
df.iloc[10:16]
# Out:
#      #                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 10   8                Wartortle  Water     NaN  59      63       80       65
# 11   9                Blastoise  Water     NaN  79      83      100       85
# 12   9  BlastoiseMega Blastoise  Water     NaN  79     103      120      135
# 13  10                 Caterpie    Bug     NaN  45      30       35       20
# 14  11                  Metapod    Bug     NaN  50      20       55       25
# 15  12               Butterfree    Bug  Flying  60      45       50       90
#
#     Sp. Def  Speed  Generation  Legendary
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 13       20     45           1      False
# 14       25     30           1      False
# 15       80     70           1      False

# %%
df.iloc[11,0]
# Out:
# 9

# %%
df.iloc[30:46,0:2].iloc[1:2,0]
# Out:
# 31    26
# Name: #, dtype: int64

# %%
df["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df[["Legendary","Type 1"]].value_counts()
# Out:
# Legendary  Type 1
# False      Water       108
#            Normal       96
#            Bug          69
#            Grass        67
#            Fire         47
#            Psychic      43
#            Electric     40
#            Rock         40
#            Ghost        30
#            Dark         29
#            Poison       28
#            Ground       28
#            Fighting     27
#            Steel        23
#            Ice          22
#            Dragon       20
#            Fairy        16
# True       Psychic      14
#            Dragon       12
#            Fire          5
#            Ground        4
#            Steel         4
#            Rock          4
#            Water         4
#            Electric      4
#            Grass         3
#            Ghost         2
# False      Flying        2
# True       Ice           2
#            Normal        2
#            Dark          2
#            Flying        2
#            Fairy         1
# dtype: int64

# %%
q=df[df["Legendary"]==True]
q["Type 1"].value_counts()
# Out:
# Psychic     14
# Dragon      12
# Fire         5
# Ground       4
# Electric     4
# Rock         4
# Steel        4
# Water        4
# Grass        3
# Ice          2
# Dark         2
# Ghost        2
# Flying       2
# Normal       2
# Fairy        1
# Name: Type 1, dtype: int64

# %%
df[df["Type 1"]=="Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df[df["Type 1"]=="Fire"].head()
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
df.sort_values(["Name"])                              # ascending order
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     NaN   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Name"]).reset_index()             # then reset index
# Out:
#      index    #                     Name   Type 1  Type 2   HP  Attack  \
# 0      510  460                Abomasnow    Grass     Ice   90      92
# 1      511  460  AbomasnowMega Abomasnow    Grass     NaN   90     132
# 2       68   63                     Abra  Psychic     NaN   25      20
# 3      392  359                    Absol     Dark     NaN   65     130
# 4      393  359          AbsolMega Absol     Dark     NaN   65     150
# ..     ...  ...                      ...      ...     ...  ...     ...
# 795    632  571                  Zoroark     Dark     NaN   60     105
# 796    631  570                    Zorua     Dark     NaN   40      65
# 797     46   41                    Zubat   Poison  Flying   40      45
# 798    695  634                 Zweilous     Dark  Dragon   72      85
# 799    794  718         Zygarde50% Forme   Dragon  Ground  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Name"],ascending=False)                      # descending order
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     NaN   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Type 1","Attack"],ascending=[True,False])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 137  127        PinsirMega Pinsir    Bug    Flying  65     155      120
# 19    15    BeedrillMega Beedrill    Bug    Poison  65     150       40
# 229  212        ScizorMega Scizor    Bug     Steel  70     150      140
# 650  589               Escavalier    Bug     Steel  70     135      105
# ..   ...                      ...    ...       ...  ..     ...      ...
# 405  370                  Luvdisc  Water       NaN  43      30       55
# 198  183                   Marill  Water     Fairy  70      20       50
# 508  458                  Mantyke  Water    Flying  45      20       50
# 381  349                   Feebas  Water       NaN  20      15       20
# 139  129                 Magikarp  Water       NaN  20      10       55
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Type 1","Attack"],ascending=[True,True])
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 230  213                Shuckle    Bug    Rock   20      10      230       10
# 14    11                Metapod    Bug     NaN   50      20       55       25
# 179  165                 Ledyba    Bug  Flying   40      20       30       40
# 733  665                 Spewpa    Bug     NaN   45      22       60       27
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 107   99                Kingler  Water     NaN   55     130      115       50
# 349  319  SharpedoMega Sharpedo  Water    Dark   70     140       70      110
# 283  260  SwampertMega Swampert  Water  Ground  100     150      110       95
# 422  382    KyogrePrimal Kyogre  Water     NaN  100     150       90      180
# 141  130  GyaradosMega Gyarados  Water    Dark   95     155      109       70
#
# ...

# %%
df["Total"]=df.iloc[:,2:8].sum(axis=1)     # add new row + sum

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# col=list(df.columns)

# %%
# col

# %%
# df=df[col[0:2]+[col[-1]]+col[2:10]]                    # arrange columns

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    208
# ...

# %%
mon=df.drop(columns=["HP","Attack","Defense","Sp. Atk","Sp. Def","Speed"])

# %%
mon
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  Poison           1      False    208
# 1      2                Ivysaur    Grass  Poison           1      False    265
# 2      3               Venusaur    Grass  Poison           1      False    345
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False    425
# 4      4             Charmander     Fire     NaN           1      False    194
# ..   ...                    ...      ...     ...         ...        ...    ...
# 795  719                Diancie     Rock   Fairy           6       True    400
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True    480
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True    400
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True    470
# 799  721              Volcanion     Fire   Water           6       True    440
#
# [800 rows x 7 columns]

# %%
mon.to_csv("new_pok.csv",index=False)                       # New file create ( CSV )

# %%
mon
# Out:
#        #                   Name   Type 1  Type 2  Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  Poison           1      False    208
# 1      2                Ivysaur    Grass  Poison           1      False    265
# 2      3               Venusaur    Grass  Poison           1      False    345
# 3      3  VenusaurMega Venusaur    Grass  Poison           1      False    425
# 4      4             Charmander     Fire     NaN           1      False    194
# ..   ...                    ...      ...     ...         ...        ...    ...
# 795  719                Diancie     Rock   Fairy           6       True    400
# 796  719    DiancieMega Diancie     Rock   Fairy           6       True    480
# 797  720    HoopaHoopa Confined  Psychic   Ghost           6       True    400
# 798  720     HoopaHoopa Unbound  Psychic    Dark           6       True    470
# 799  721              Volcanion     Fire   Water           6       True    440
#
# [800 rows x 7 columns]

# %%
df[(df["Type 1"]=="Grass") | (df["Legendary"]==True)]           #  | = Or operator
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 48    43                 Oddish    Grass  Poison  45      50       55
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    208
# ...

# %%
df[(df["Type 1"]=="Grass") & (df["Legendary"]==True)]                               # & = and opreator
# Out:
#        #               Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 550  492  ShayminLand Forme  Grass       NaN  100     100      100      100
# 551  492   ShayminSky Forme  Grass    Flying  100     103       75      120
# 701  640           Virizion  Grass  Fighting   91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 550      100    100           4       True    400
# 551       75    127           4       True    398
# 701      129    108           5       True    343

# %%
df.iloc[np.where((df["HP"]==min(df["HP"]))  |  (df["Attack"]==max(df["Attack"])))]
# Out:
#        #                 Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 316  292             Shedinja      Bug     Ghost    1      90       45
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 163      154      100    130           1       True    550
# 316       30       30     40           3      False    166

# %%
df[(df["Type 1"]=="Grass") & (df["Generation"]==6)&(df["Attack"]>100)]
# Out:
#        #        Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 720  652  Chesnaught  Grass    NaN  88     107      122       74       75
#
#      Speed  Generation  Legendary  Total
# 720     64           6      False    391

# %%
df[df["Type 1"]=="Water"]="Aqua"

# %%
df["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Aqua', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)
